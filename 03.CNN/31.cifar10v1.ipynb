# %% [markdown]
# ### Cifar-10 이미지 분류 v1

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2023
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 탐색 및 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'dear', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(8, 2))
for i in range(10):
  plt.subplot(1, 10, i+1)
  plt.imshow(X_train[i]), plt.xticks([]), plt.yticks([])
  plt.title(class_names[y_train[i, 0]], fontsize=8)
plt.show()

# %%
# X data scaling
X_train = X_train / 255.
X_test = X_test / 255.

# %%
# y data one-hot-encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([
    Conv2D(32, (3,3), input_shape=X_train.shape[1:], padding='same', activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1250858 (4.77 MB)
# Trainable params: 1250858 (4.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile('adam', 'categorical_crossentropy', ['accuracy'])

model_path = 'best-cifar10-v1.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=5)

# %%
hist = model.fit(X_train, Y_train, validation_split=0.2,
                 epochs=100, batch_size=32, callbacks=[mc, es])
# Out:
# Epoch 1/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 1.5674 - accuracy: 0.4306
# Epoch 1: val_loss improved from inf to 1.17834, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 21s 7ms/step - loss: 1.5664 - accuracy: 0.4310 - val_loss: 1.1783 - val_accuracy: 0.5795
# Epoch 2/100
#   23/1250 [..............................] - ETA: 6s - loss: 1.2036 - accuracy: 0.5421
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1241/1250 [============================>.] - ETA: 0s - loss: 1.1642 - accuracy: 0.5850
# Epoch 2: val_loss improved from 1.17834 to 0.96679, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 1.1628 - accuracy: 0.5855 - val_loss: 0.9668 - val_accuracy: 0.6578
# Epoch 3/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 1.0062 - accuracy: 0.6468
# Epoch 3: val_loss improved from 0.96679 to 0.93503, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 1.0060 - accuracy: 0.6469 - val_loss: 0.9350 - val_accuracy: 0.6743
# Epoch 4/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.9109 - accuracy: 0.6779
# Epoch 4: val_loss improved from 0.93503 to 0.88304, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.9115 - accuracy: 0.6777 - val_loss: 0.8830 - val_accuracy: 0.6920
# Epoch 5/100
# 1240/1250 [============================>.] - ETA: 0s - loss: 0.8491 - accuracy: 0.7046
# Epoch 5: val_loss improved from 0.88304 to 0.75815, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.8486 - accuracy: 0.7049 - val_loss: 0.7581 - val_accuracy: 0.7315
# Epoch 6/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.7938 - accuracy: 0.7209
# Epoch 6: val_loss improved from 0.75815 to 0.75438, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7939 - accuracy: 0.7209 - val_loss: 0.7544 - val_accuracy: 0.7398
# Epoch 7/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.7544 - accuracy: 0.7366
# Epoch 7: val_loss improved from 0.75438 to 0.72516, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.7539 - accuracy: 0.7365 - val_loss: 0.7252 - val_accuracy: 0.7475
# Epoch 8/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.7173 - accuracy: 0.7474
# Epoch 8: val_loss improved from 0.72516 to 0.72294, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.7174 - accuracy: 0.7474 - val_loss: 0.7229 - val_accuracy: 0.7495
# Epoch 9/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6853 - accuracy: 0.7603
# Epoch 9: val_loss improved from 0.72294 to 0.71583, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6851 - accuracy: 0.7605 - val_loss: 0.7158 - val_accuracy: 0.7592
# Epoch 10/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.6531 - accuracy: 0.7698
# Epoch 10: val_loss improved from 0.71583 to 0.70715, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.6532 - accuracy: 0.7696 - val_loss: 0.7071 - val_accuracy: 0.7559
# Epoch 11/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6270 - accuracy: 0.7786
# Epoch 11: val_loss did not improve from 0.70715
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6271 - accuracy: 0.7787 - val_loss: 0.7242 - val_accuracy: 0.7543
# Epoch 12/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6053 - accuracy: 0.7857
# Epoch 12: val_loss improved from 0.70715 to 0.68723, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6049 - accuracy: 0.7860 - val_loss: 0.6872 - val_accuracy: 0.7697
# Epoch 13/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.5864 - accuracy: 0.7942
# Epoch 13: val_loss did not improve from 0.68723
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.5865 - accuracy: 0.7941 - val_loss: 0.6983 - val_accuracy: 0.7629
# Epoch 14/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.5668 - accuracy: 0.8005
# Epoch 14: val_loss improved from 0.68723 to 0.68604, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.5667 - accuracy: 0.8005 - val_loss: 0.6860 - val_accuracy: 0.7674
# Epoch 15/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.5568 - accuracy: 0.8022
# Epoch 15: val_loss did not improve from 0.68604
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.5567 - accuracy: 0.8022 - val_loss: 0.7087 - val_accuracy: 0.7640
# Epoch 16/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.5401 - accuracy: 0.8081
# Epoch 16: val_loss did not improve from 0.68604
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.5404 - accuracy: 0.8081 - val_loss: 0.6890 - val_accuracy: 0.7673
# Epoch 17/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.5204 - accuracy: 0.8146
# Epoch 17: val_loss improved from 0.68604 to 0.67209, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.5203 - accuracy: 0.8146 - val_loss: 0.6721 - val_accuracy: 0.7725
# Epoch 18/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.5090 - accuracy: 0.8194
# Epoch 18: val_loss did not improve from 0.67209
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.5091 - accuracy: 0.8195 - val_loss: 0.7461 - val_accuracy: 0.7652
# Epoch 19/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.5018 - accuracy: 0.8241
# Epoch 19: val_loss did not improve from 0.67209
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.5017 - accuracy: 0.8241 - val_loss: 0.6746 - val_accuracy: 0.7769
# Epoch 20/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.4865 - accuracy: 0.8290
# Epoch 20: val_loss did not improve from 0.67209
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.4865 - accuracy: 0.8290 - val_loss: 0.6963 - val_accuracy: 0.7676
# Epoch 21/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.4743 - accuracy: 0.8319
# Epoch 21: val_loss improved from 0.67209 to 0.66964, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.4741 - accuracy: 0.8318 - val_loss: 0.6696 - val_accuracy: 0.7835
# Epoch 22/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.4723 - accuracy: 0.8349
# Epoch 22: val_loss improved from 0.66964 to 0.66898, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.4723 - accuracy: 0.8349 - val_loss: 0.6690 - val_accuracy: 0.7827
# Epoch 23/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.4596 - accuracy: 0.8382
# Epoch 23: val_loss did not improve from 0.66898
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.4593 - accuracy: 0.8383 - val_loss: 0.6864 - val_accuracy: 0.7840
# Epoch 24/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.4544 - accuracy: 0.8394
# Epoch 24: val_loss did not improve from 0.66898
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.4546 - accuracy: 0.8393 - val_loss: 0.7137 - val_accuracy: 0.7825
# Epoch 25/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.4410 - accuracy: 0.8467
# Epoch 25: val_loss did not improve from 0.66898
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.4410 - accuracy: 0.8467 - val_loss: 0.6724 - val_accuracy: 0.7873
# Epoch 26/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.4333 - accuracy: 0.8486
# Epoch 26: val_loss did not improve from 0.66898
# 1250/1250 [==============================] - 7s 5ms/step - loss: 0.4333 - accuracy: 0.8486 - val_loss: 0.6915 - val_accuracy: 0.7852
# Epoch 27/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.4407 - accuracy: 0.8457
# Epoch 27: val_loss did not improve from 0.66898
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.4407 - accuracy: 0.8457 - val_loss: 0.6779 - val_accuracy: 0.7801

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6938 - accuracy: 0.7723
# [0.6938084363937378, 0.7723000049591064]

# %% [markdown]
# - 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc) + 1)

# %%
plt.figure(figsize=(12, 6))
plt.plot(xs, y_acc, label='Train Accuracy')
plt.plot(xs, y_vloss, label='Validation Loss')
plt.legend(), plt.grid(), plt.xlabel('epoch')
plt.title('Cifar-10 CNN Model v1')
plt.show()
